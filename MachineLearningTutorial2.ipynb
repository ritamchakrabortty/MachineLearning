# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv("/content/homeprices2.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
df.bedrooms.median()
# Out:
# 3.5

# %%
import math
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
df.bedrooms.fillna(median_bedrooms)
# Out:
# 0    3.0
# 1    4.0
# 2    3.0
# 3    3.0
# 4    5.0
# Name: bedrooms, dtype: float64

# %%
df.bedrooms=df.bedrooms.fillna(median_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
reg.intercept_
# Out:
# 383724.9999999998

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([444400.])

# %%
reg.predict([[3000,4,15]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([589000.])

# %%
reg.predict([[2500,4,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([588625.])

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(Rs)')
plt.scatter(df.area,df.price, color='red',marker='*')
plt.plot(df.area,df.price,color='blue')

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(Rs)')
plt.scatter(df.area,df.price, color='red',marker='*')
plt.plot(df.area,reg.predict(df[['area','bedrooms','age']]),color='blue')

# %%
# %matplotlib inline
plt.xlabel('bedrooms(number)')
plt.ylabel('price(Rs)')
plt.scatter(df.bedrooms,df.price, color='red',marker='*')
plt.plot(df.bedrooms,df.price,color='green')

# %%
# %matplotlib inline
plt.xlabel('bedrooms(number)')
plt.ylabel('price(Rs)')
plt.scatter(df.bedrooms,df.price, color='red',marker='*')
plt.plot(df.bedrooms,reg.predict(df[['area','bedrooms','age']]),color='green')

# %%
# %matplotlib inline
plt.xlabel('age(years)')
plt.ylabel('price(Rs)')
plt.scatter(df.age,df.price, color='red',marker='*')
plt.plot(df.age,df.price,color='brown')

# %%
# %matplotlib inline
plt.xlabel('age(years)')
plt.ylabel('price(Rs)')
plt.scatter(df.age,df.price, color='red',marker='*')
plt.plot(df.age,reg.predict(df[['area','bedrooms','age']]),color='brown')
